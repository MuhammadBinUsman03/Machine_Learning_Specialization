# %% [markdown]
# # **INTRODUCTION** :
#
# Exploratory data analysis (EDA) serves as a crucial first step in any data-driven project. It allows us to uncover hidden patterns, identify relationships, and gain a deeper understanding of the dataset. By examining and visualizing the data, we can extract meaningful information, make informed decisions, and drive actionable insights.
# #  Aims and Objectives:
# Our primary objective is to explore the Google Playstore dataset using various statistical and visual techniques. We will analyze different attributes such as app ratings, reviews, categories, sizes, and more. By asking pertinent questions and employing effective data exploration methods, we aim to uncover trends, patterns, and correlations within the dataset.
#
# Throughout this project, we will utilize popular data analysis tools and techniques to extract meaningful insights. We will leverage Python programming language along with libraries such as pandas, NumPy, and matplotlib to perform data cleaning, manipulation, and visualization. By applying statistical methods and visualizing the data, we will uncover intriguing patterns and relationships, which will inform our decision-making and provide valuable insights.

# %% [markdown]
# # **DATA** :
#
# In this project, we will be working with the Google Playstore dataset, a comprehensive collection of information about various applications available on the Play Store. With over 100,000 apps in the dataset, it provides us with a rich and diverse sample of the app ecosystem. The dataset, obtained from Kaggle. By delving into this dataset, we aim to gain valuable insights into the characteristics, trends, and patterns exhibited by the vast array of apps in the Google Play Store.
#
#
# #  Source:
#
# The Google Playstore dataset was acquired by downloading it from Kaggle (openly available there) using the OpenDatasets library as a CSV file and then loaded into this ipynb file using Pandas. This library facilitated the retrieval and storage of the dataset directly into the notebook, allowing for seamless access and analysis. The kaggle allows and offer each user an API key to download its publicly available datasets.
# In this project we're using a subset of the original dataset. Hence the dataset has approx size 8.5 MB
#
# ↪ *Google Platstore Dataset link*🔗 [*kaggle link*](https://www.kaggle.com/datasets/gauthamp10/google-playstore-apps)
#
# #  Relevancy with project:
#  By exploring the dataset, importing external knowledge, and applying systematic approaches, valuable insights can be gained regarding app performance, user preferences, and market trends. Critical analysis, reflection, and effective communication of findings enhance the overall quality and usefulness of the analysis. The dataset offers opportunities to identify gaps, refine data, and extract meaningful insights for various stakeholders in the mobile app ecosystem.

# %% [markdown]
# # **PROJECT BACKGROUND**
# This project is relevant for learning exploratory data analysis as it provides a real-world dataset, the Google Playstore dataset, that allows learners to apply and practice various techniques, tools, and methodologies for uncovering insights and patterns in a large-scale dataset.
#
# We would like to find out which category of apps is most popular and among popular apps what are the similarities.
# Our data pipeline consists of following steps and stages:
#
# `Data Acquisition` Downloading the Google Playstore dataset from Kaggle.
#
# `Data Preparation and Cleaning` Preparing the dataset by handling missing values, removing duplicates, and transforming data into a suitable format for analysis.
#
# `Exploratory Analysis and Visualizations` Conducting exploratory analysis to understand the dataset's characteristics, relationships, and patterns using statistical techniques and visualizations.
#
# `Question and Answers` Formulating specific research questions and finding answers by analyzing the data, exploring correlations, and deriving insights.
#
# `Summary and Conclusion` Summarizing the findings, drawing conclusions based on the analysis, and providing actionable insights or recommendations based on the results of the data analysis.
#
# `Further Analysis` Predict rating through a machine learning pipeline

# %% [markdown]
# ## Importing the dependecies
# We have used the following libraries assisting us in analysis
#
# `pandas` is easy to use and offer various data structures and data analysis tools for python. It allows for fast analysis and data cleaning and preparation.
#
# `NumPy` is a library for Python that adds support for large, multi-dimensional arrays and matrices
#
# `Matplotlib` is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# `Seaborn` provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Preparation and Cleaing
#  ↪ Load the csv file with the pandas
#
#  ↪ creating the dataframe and understanding the data present in the dataset
#
#  ↪ Dealing with the missing data and the incorrect records

# %%
df = pd.read_csv('Google-Playstore.csv')

# %% [markdown]
#  viewing the first 5 rows of the datset

# %%
df.head(5)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0              10.0                15  True    0.0      USD   10M
# 1            5000.0              7662  True    0.0      USD  2.9M
# 2              50.0                58  True    0.0      USD  3.7M
# 3              10.0                19  True    0.0      USD  1.8M
# 4             100.0               478  True    0.0      USD  6.2M
#
#   Minimum Android                       Developer Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1      5.0 and up                         Webserveis
# 2    4.0.3 and up                         Cabin Crew
# 3    4.0.3 and up                Climate Smart Tech2
# 4      4.1 and up              Rafal Milek-Horodyski
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy  Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/         False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/          True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...         False
# 3                                                NaN          True
# 4                        http://www.horodyski.com.pl         False
#
#    In App Purchases  Editors Choice         Scraped Time
# 0             False           False  2021-06-15 20:19:35
# 1             False           False  2021-06-15 20:19:35
# 2             False           False  2021-06-15 20:19:35
# 3             False           False  2021-06-15 20:19:35
# 4             False           False  2021-06-15 20:19:35

# %% [markdown]
# Let's see what are the columns were given in the Google-Playstore dataset

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %% [markdown]
# let's see the shape of the dataset

# %%
df.shape
# Out:
# (30000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           30000 non-null  object
#  1   App Id             30000 non-null  object
#  2   Category           30000 non-null  object
#  3   Rating             29729 non-null  float64
#  4   Rating Count       29729 non-null  float64
#  5   Installs           29999 non-null  object
#  6   Minimum Installs   29999 non-null  float64
#  7   Maximum Installs   30000 non-null  int64
#  8   Free               30000 non-null  bool
#  9   Price              30000 non-null  float64
#  10  Currency           29999 non-null  object
#  11  Size               30000 non-null  object
#  12  Minimum Android    29913 non-null  object
#  13  Developer Id       30000 non-null  object
#  14  Developer Website  20141 non-null  object
#  15  Developer Email    30000 non-null  object
#  16  Released           29148 non-null  object
#  17  Last Updated       30000 non-null  object
#  18  Content Rating     30000 non-null  object
#  19  Privacy Policy     24588 non-null  object
#  20  Ad Supported       30000 non-null  bool
#  21  In App Purchases   30000 non-null  bool
#  22  Editors Choice     30000 non-null  bool
#  23  Scraped Time       30000 non-null  object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 4.7+ MB

# %% [markdown]
# ## Observation:
#
# ---
# 1. The dataset having   2312944 rows and 24 columns
# 2. The columns in the dataset are:
#
#         'App Name', 'App Id', 'Category', 'Rating', 'Rating Count, Installs','Minimum Installs', 'Maximum Installs', 'Free', 'Price',
#         'Currency','Size', 'Minimum Android', 'Developer Id', 'Developer Website','Developer Email', 'Released', 'Last Updated',
#         'Content Rating','Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice','Scraped Time'

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  29729.000000  2.972900e+04      2.999900e+04      3.000000e+04
# mean       2.215820  1.853731e+03      1.534008e+05      2.468250e+05
# std        2.109195  4.052426e+04      6.707192e+06      1.019171e+07
# min        0.000000  0.000000e+00      0.000000e+00      0.000000e+00
# 25%        0.000000  0.000000e+00      5.000000e+01      8.600000e+01
# 50%        3.000000  6.000000e+00      5.000000e+02      6.985000e+02
# 75%        4.300000  4.300000e+01      5.000000e+03      7.546750e+03
# max        5.000000  4.275556e+06      1.000000e+09      1.616141e+09
#
#               Price
# count  30000.000000
# mean       0.109955
# std        2.758434
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      399.990000

# %% [markdown]
# ## Observation :
#
# ---
# 1. we have 5 numerical columns in our dataset

# %% [markdown]
# To look the entire columns we can use pandas functon pd.set_option()

# %%
 pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0              10.0                15  True    0.0      USD   10M
# 1            5000.0              7662  True    0.0      USD  2.9M
# 2              50.0                58  True    0.0      USD  3.7M
# 3              10.0                19  True    0.0      USD  1.8M
# 4             100.0               478  True    0.0      USD  6.2M
#
#   Minimum Android                       Developer Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1      5.0 and up                         Webserveis
# 2    4.0.3 and up                         Cabin Crew
# 3    4.0.3 and up                Climate Smart Tech2
# 4      4.1 and up              Rafal Milek-Horodyski
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy  Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/         False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/          True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...         False
# 3                                                NaN          True
# 4                        http://www.horodyski.com.pl         False
#
#    In App Purchases  Editors Choice         Scraped Time
# 0             False           False  2021-06-15 20:19:35
# 1             False           False  2021-06-15 20:19:35
# 2             False           False  2021-06-15 20:19:35
# 3             False           False  2021-06-15 20:19:35
# 4             False           False  2021-06-15 20:19:35

# %% [markdown]
# ## Missing values in the data

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer Website    9859
# Privacy Policy       5412
# Released              852
# Rating                271
# Rating Count          271
# Minimum Android        87
# Installs                1
# Minimum Installs        1
# Currency                1
# Developer Email         0
# Editors Choice          0
# In App Purchases        0
# Ad Supported            0
# Content Rating          0
# Last Updated            0
# App Name                0
# Developer Id            0
# App Id                  0
# Size                    0
# Price                   0
# Free                    0
# Maximum Installs        0
# Category                0
# Scraped Time            0
# dtype: int64

# %% [markdown]
# # **Exploratory Analysis and Visualization**

# %% [markdown]
# ## Let's plot the missing null values

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'viridis')
plt.title("Missing null values")
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# Let's see the missing percentage in data

# %%
missing_percentage = df.isnull().sum().sort_values(ascending = False)/len(df)
missing_percentage
# Out:
# Developer Website    0.328633
# Privacy Policy       0.180400
# Released             0.028400
# Rating               0.009033
# Rating Count         0.009033
# Minimum Android      0.002900
# Installs             0.000033
# Minimum Installs     0.000033
# Currency             0.000033
# Developer Email      0.000000
# Editors Choice       0.000000
# In App Purchases     0.000000
# Ad Supported         0.000000
# Content Rating       0.000000
# Last Updated         0.000000
# App Name             0.000000
# Developer Id         0.000000
# App Id               0.000000
# Size                 0.000000
# Price                0.000000
# Free                 0.000000
# Maximum Installs     0.000000
# Category             0.000000
# Scraped Time         0.000000
# dtype: float64

# %% [markdown]
# ## Let's plot the missing percentage of null values

# %%
missing_percentage = missing_percentage[missing_percentage != 0] # Only the missing data
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,6)
missing_percentage.plot(kind = 'barh')
plt.title("Missig percentage of null values")
# Out:
# Text(0.5, 1.0, 'Missig percentage of null values')

# %% [markdown]
# ## Observation :
#
#
# Dealing with the null values
#
#
# 1. The columns having highest percentage of null values are :
# * Developer Website
# * Privacy Policy
#
# these two are not that much helpful if we want we can drop these columns and in the further steps we drop and add some features in the dataset after the Analysis.
#
# 2. Although here, there seems no null values for the column size, Developer Id,Developer, we can drop the small null values for these columns
#
# * Currency
# * Installs
# * Minimum Installs
#
# 3. Rating,Rating Count,Released are important column so it is good to fill the null values.
#
# * Rating
# * Rating count
# * Minimum Andriod
# * Released

# %% [markdown]
# ## from observation 2 droping the null values of the columns got selected

# %%
df.dropna(subset = ['Currency','Installs','Minimum Installs'], inplace = True)

# %%
df.isnull().sum()
# Out:
# App Name                0
# App Id                  0
# Category                0
# Rating                270
# Rating Count          270
# Installs                0
# Minimum Installs        0
# Maximum Installs        0
# Free                    0
# Price                   0
# Currency                0
# Size                    0
# Minimum Android        87
# Developer Id            0
# Developer Website    9859
# Developer Email         0
# Released              851
# Last Updated            0
# Content Rating          0
# Privacy Policy       5412
# Ad Supported            0
# In App Purchases        0
# Editors Choice          0
# Scraped Time            0
# dtype: int64

# %% [markdown]
# ## Now let's start cleaning the each row

# %% [markdown]
# checking any duplicates in the App Name

# %%
boolean = df['App Name'].duplicated().any()
boolean
# Out:
# True

# %%
df['App Name'].value_counts()
# Out:
# Shopping List                           4
# Tip Calculator                          4
# Tic Tac Toe                             4
# BMI Calculator                          4
# Flashlight                              4
#                                        ..
# Kazakh Lao Dictionary +                 1
# Moral Stories in English                1
# Hopkinsville YMCA                       1
# Charles W Thomas Salon                  1
# Casual Pool 8 - American 8 Ball Pool    1
# Name: App Name, Length: 29894, dtype: int64

# %% [markdown]
# from the above cell output we can see that App Name column has multiple rows. Let's check out that data in those rows is identical or not

# %%
df[df['App Name'] == 'Tic Tac Toe']
# Out:
#           App Name                       App Id Category  Rating  \
# 3918   Tic Tac Toe     com.dev.atte.tic_tac_toe   Puzzle     0.0
# 13758  Tic Tac Toe             com.md.tictactoe    Board     0.0
# 25351  Tic Tac Toe  com.sthirumuru.tictactoenew    Board     4.2
# 28142  Tic Tac Toe         com.fsk00x.TicTacToe    Board     0.0
#
#        Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 3918            0.0      10+              10.0                30  True    0.0
# 13758           0.0      10+              10.0                31  True    0.0
# 25351          11.0   5,000+            5000.0              6379  True    0.0
# 28142           0.0     500+             500.0               922  True    0.0
#
#       Currency  Size Minimum Android             Developer Id  \
# 3918       USD  3.4M      4.0 and up        ATTE AKA FRANCOIS
# 13758      USD   34M      4.3 and up      Smart Digital Tools
# 25351      USD  7.4M      7.0 and up  Sundeep Reddy Thirumuru
# 28142      USD  8.6M      4.1 and up          SteadFast Games
#
#                        Developer Website              Developer Email  \
# 3918   https://ne2ad32ee.app-ads-txt.com  dev.atte.francois@gmail.com
# 13758                                NaN         msms.zaman@gmail.com
# 25351                                NaN  sundeep.thirumuru@gmail.com
# 28142                                NaN        devmethyl@outlook.com
#
#            Released  Last Updated Content Rating  \
# 3918   May 18, 2018  May 18, 2018       Everyone
# 13758   Nov 2, 2020  Nov 18, 2020       Everyone
# 25351  Apr 13, 2021  Jun 03, 2021       Everyone
# 28142  Feb 13, 2020  Feb 13, 2020       Everyone
#
#                                           Privacy Policy  Ad Supported  \
# 3918                                                 NaN          True
# 13758  https://smartdailytools.blogspot.com/2020/09/p...          True
# 25351                                                NaN          True
# 28142                                                NaN          True
#
#        In App Purchases  Editors Choice         Scraped Time
# 3918              False           False  2021-06-15 20:23:22
# 13758             False           False  2021-06-15 20:32:58
# 25351             False           False  2021-06-15 20:44:27
# 28142             False           False  2021-06-15 20:47:17

# %%
df['App Id'].duplicated().any()
# Out:
# False

# %%
df['App Id'].value_counts()
# Out:
# com.ishakwe.gakondo                  1
# com.cloudstream.deluxrealty.delux    1
# com.acr1992.choklo                   1
# com.credianz.colorfulfish            1
# com.voic.clickandtalk                1
#                                     ..
# co.thor.zassx                        1
# com.SmartCentre.math_tables          1
# avcisoft.resistorcolormatik          1
# com.thisisglobal.player.classic      1
# com.exubit.billiard                  1
# Name: App Id, Length: 29999, dtype: int64

# %% [markdown]
#
# 1. we have the Apps with the same names but with the unique App IDs so the Apps are differed based on the App IDs

# %% [markdown]
# ## let's Explore the numerical columns

# %%
df['Installs'].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', '50,000,000+',
#        '1,000,000,000+', '500,000,000+'], dtype=object)

# %% [markdown]
# It is in the object type, we need to change it into the int type

# %%
df['Installs'] = df['Installs'].str.split('+').str[0]    # reomoves the + symbol
df['Installs'].replace(',','', regex=True, inplace=True) #replace the commas ',' in the install column
df['Installs'] = df['Installs'].astype(int)              # converting it to the int type

# %%
df['Installs'].unique()
# Out:
# array([        10,       5000,         50,        100,       1000,
#               500,      50000,      10000,          1,     500000,
#            100000,          5,   10000000,    1000000,    5000000,
#                 0,  100000000,   50000000, 1000000000,  500000000])

# %%
df['Currency'].unique()
# Out:
# array(['USD', 'XXX', 'CAD', 'EUR', 'INR', 'VND', 'GBP', 'BRL', 'KRW'],
#       dtype=object)

# %%
df['Size'].unique()
# Out:
# array(['10M', '2.9M', '3.7M', '1.8M', '6.2M', '46M', '2.5M', '16M',
#        '1.3M', '3.5M', '51M', '2.7M', '7.6M', '15M', '29M', '12M', '2.0M',
#        '70M', '11M', '24M', '1.4M', '20M', '2.4M', '25M', '21M', '36M',
#        '6.1M', '2.6M', '8.9M', '3.9M', '30M', '26M', '4.9M', '4.3M',
#        '4.8M', '4.6M', '2.8M', '38M', '5.1M', '147M', '33M', '2.2M',
#        '7.1M', '27M', '18M', '7.7M', '32M', '19M', '39M', '31M', '1.2M',
#        '3.1M', '3.2M', '42M', '22M', '4.1M', '50M', '5.5M', '127k',
#        '8.4M', '41M', '49M', '7.0M', '4.7M', '43M', '5.4M', '3.0M',
#        '1.6M', '2.1M', '37M', '3.6M', '9.0M', '9.9M', '67M', '28M',
#        'Varies with device', '7.9M', '3.3M', '6.0M', '5.7M', '9.8M',
#        '5.0M', '1.7M', '7.4M', '1.9M', '3.8M', '6.4M', '8.1M', '6.5M',
#        '4.4M', '45M', '7.2M', '13M', '6.9M', '60M', '6.6M', '4.0M', '17M',
#        '4.2M', '58M', '93M', '9.7M', '23M', '52M', '5.6M', '48M', '1.5M',
#        '8.5M', '54M', '62M', '133M', '64M', '152M', '136M', '9.5M',
#        '4.5M', '40M', '531k', '8.0M', '2.3M', '35M', '83M', '7.3M',
#        '6.7M', '9.4M', '69M', '7.5M', '343k', '84M', '5.9M', '6.3M',
#        '1,018k', '34M', '63M', '3.4M', '57M', '14M', '86M', '9.2M',
#        '142M', '6.8M', '9.1M', '9.6M', '44M', '1.0M', '886k', '53M',
#        '91M', '61M', '5.2M', '188k', '5.3M', '8.3M', '8.2M', '79M',
#        '9.3M', '47M', '107M', '8.6M', '95M', '56M', '5.8M', '71M', '78M',
#        '7.8M', '59M', '72M', '8.7M', '200k', '92k', '75M', '966k', '844k',
#        '963k', '151M', '274k', '145M', '8.8M', '82M', '10.0M', '66M',
#        '240k', '101M', '76M', '96M', '139M', '212k', '101k', '125M',
#        '111M', '1.1M', '116M', '94M', '99M', '194k', '89M', '55M', '506k',
#        '85M', '98M', '122M', '88M', '77M', '138k', '659k', '880k', '106M',
#        '87M', '230k', '97M', '989k', '453k', '201M', '28k', '562k',
#        '745k', '68M', '118M', '357k', '74M', '600k', '22k', '73M', '144M',
#        '33k', '250M', '359k', '81M', '112M', '298k', '351k', '1,007k',
#        '145k', '936k', '65M', '25k', '986k', '512k', '102M', '842k',
#        '962k', '497k', '321k', '565k', '946k', '222k', '998k', '82k',
#        '105M', '257k', '390k', '18k', '100M', '727k', '176k', '113M',
#        '531M', '120M', '229k', '141M', '130M', '92M', '90M', '150k',
#        '150M', '136k', '80M', '156M', '449k', '121M', '945k', '969k',
#        '329k', '243k', '143M', '574k', '261k', '917k', '742k', '137M',
#        '159M', '760k', '48k', '815k', '629k', '422M', '77k', '393k',
#        '895k', '813k', '149M', '266k', '134M', '786k', '687k', '251k',
#        '259k', '221k', '803k', '224k', '898k', '66k', '128M', '476k',
#        '253k', '124k', '214k', '24k', '230M', '163k', '1,019k', '228k',
#        '420k', '103M', '631k', '990k', '801k', '57k', '389k', '563k',
#        '205k', '21k', '146M', '567k', '344k', '94k', '750k', '407k',
#        '114M', '912k', '138M', '889k', '445k', '117M', '571k', '810k',
#        '318k', '50k', '805k', '110M', '130k', '743k', '158M', '894k',
#        '808k', '148M', '127M', '588k', '269k', '738k', '109M', '382k',
#        '501k', '282k', '153M', '260k', '405k', '543k', '924k', '162M',
#        '837k', '823k', '826k', '244k', '663k', '119M', '379k', '132M',
#        '595k', '234k', '165M', '104M', '761k', '872k', '143k', '528k',
#        '774k', '648k', '123k', '879k', '433k', '461k', '818k', '140M',
#        '877k', '505k', '901k', '170k', '717k', '106k', '255k', '1,014k',
#        '477k', '316k', '216k', '123M', '723k', '935k', '124M', '1,020k',
#        '173M', '293M', '273k', '256k', '866k', '174M', '918k', '647k',
#        '154k', '157M', '286k', '395k', '573k', '140k', '315k', '827k',
#        '906k', '492k', '934k', '790k', '862k', '135M', '167M', '184M',
#        '755k', '385k', '737k', '86k', '177k', '335M', '79k', '228M',
#        '114k', '188M', '429k', '650k', '980k', '939k', '988k', '129M',
#        '198k', '519k', '762k', '620k', '724k', '132k', '591k', '129k',
#        '154M', '1,002k', '959k', '444k', '757k', '160M', '495k', '164M',
#        '920k', '15k', '721k', '977k', '665k', '941k', '108M', '539k',
#        '12k', '479k', '89k', '510M', '277k', '973k', '697k', '67k',
#        '667k', '346k', '199k', '511k', '617k', '954k', '474k', '548k',
#        '278k', '515k', '131M', '678k', '36k', '483k', '69k', '147k',
#        '876k', '1,022k', '850k', '645k', '394k', '30k', '184k', '176M',
#        '521k', '179k', '243M', '354k', '335k', '749k', '215k', '76k',
#        '885k', '236k', '1,010k', '392k', '994k', '166k', '630k', '117k',
#        '607k', '652k', '218k', '83k', '960k', '968k', '115M', '770k',
#        '206M', '68k', '360k', '848k', '387k', '207k', '457k', '263k',
#        '692k', '220k', '108k', '103k', '896k', '166M', '791k', '58k',
#        '250k', '942k', '851k', '254k', '248M', '536k', '121k', '194M',
#        '578k', '658k', '708k', '589k', '334k', '417k', '41k', '802k',
#        '59k', '922k', '580k', '338k', '674k', '210M', '32k', '42k',
#        '897k', '187M', '753k', '553k', '500k', '219k', '411k', '641k',
#        '892k', '608k', '975k', '414k', '525k', '1,001k', '189k', '178k',
#        '231M', '31k', '759k', '342k', '958k', '919k', '599k', '478k',
#        '157k', '177M', '991k', '305k', '637k', '291k', '893k', '63k',
#        '320k', '1,012k', '765k', '661k', '202M', '871k', '726k', '793k',
#        '830k', '822k', '17k', '1,000k', '180M', '710k', '413k', '763k',
#        '694k', '339k', '853k', '54k', '384k', '284k', '967k', '615k',
#        '540k', '373k', '107k', '514k', '193k', '955k', '736k', '88k',
#        '185M', '646k', '824k', '950k', '785k', '336k', '952k', '292k',
#        '943k', '246k', '719k', '198M', '109k', '61k', '582k', '722M',
#        '937k'], dtype=object)

# %% [markdown]
# The Size of data can be in GB, MB and KB let's convert the data into the size in MB, also replacing the characters M,k and G will allows us to treat size column numerically

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)

# %%
#df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
# Out:
# 0     10
# 1    2.9
# 2    3.7
# 3    1.8
# 4    6.2
# Name: Size, dtype: object

# %% [markdown]
# here we get a missmatched value with the data
# we got the value 1,018 we can drop it or we can assume as it may be a '.' (dot) the would incorrectly added to the dataset. so let assume it as dot for now and repalce the ',' with the dot '.'

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '.') if ',' in str(x) else x)

# %% [markdown]
# conversion of kbs to mb

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)

# %%
#df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# we get an another missmatch value in the data set which is 'Varies with device' it means the size of the App may vaies with the device---> but here I am assuming it as 0

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', '0') if 'Varies with device' in str(x) else x)

# %%
#df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# conversion of data Gbs to Mb. It's better to represent app size in MB format instead of GB especially for apps have sizes that fall within the range of a few mbs to a few hundred mbs

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('G', '')) * 1000 if 'G' in str(x) else x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(x))

# %%
df.dtypes['Size']
# Out:
# dtype('float64')

# %%
df['Minimum Android']
# Out:
# 0          7.1 and up
# 1          5.0 and up
# 2        4.0.3 and up
# 3        4.0.3 and up
# 4          4.1 and up
#              ...
# 29995      4.1 and up
# 29996      4.2 and up
# 29997      5.0 and up
# 29998      4.1 and up
# 29999      4.1 and up
# Name: Minimum Android, Length: 29999, dtype: object

# %%
df['Content Rating']
# Out:
# 0        Everyone
# 1        Everyone
# 2        Everyone
# 3        Everyone
# 4        Everyone
#            ...
# 29995    Everyone
# 29996    Everyone
# 29997    Everyone
# 29998    Everyone
# 29999    Everyone
# Name: Content Rating, Length: 29999, dtype: object

# %%
df['Released']
# Out:
# 0        Feb 26, 2020
# 1        May 21, 2020
# 2         Aug 9, 2019
# 3        Sep 10, 2018
# 4        Feb 21, 2020
#              ...
# 29995    May 28, 2015
# 29996    Aug 31, 2014
# 29997    Mar 29, 2021
# 29998    Apr 11, 2016
# 29999    Jul 23, 2019
# Name: Released, Length: 29999, dtype: object

# %%
df['Last Updated']
# Out:
# 0        Feb 26, 2020
# 1        May 06, 2021
# 2        Aug 19, 2019
# 3        Oct 13, 2018
# 4        Nov 12, 2018
#              ...
# 29995    Apr 07, 2021
# 29996    Jul 14, 2020
# 29997    Mar 29, 2021
# 29998    Dec 16, 2020
# 29999    Jul 13, 2020
# Name: Last Updated, Length: 29999, dtype: object

# %%
df['Privacy Policy']
# Out:
# 0                       https://beniyizibyose.tk/projects/
# 1        https://dev4phones.wordpress.com/licencia-de-uso/
# 2        https://www.vietnamairlines.com/vn/en/terms-an...
# 3                                                      NaN
# 4                              http://www.horodyski.com.pl
#                                ...
# 29995              https://zerostyle.co.jp/contact/#policy
# 29996                                                  NaN
# 29997    https://docs.google.com/document/d/1udFgW1CQcF...
# 29998    http://www.portalradios.com.br/pagina.php?&pg=...
# 29999                 http://exubit.com/casualpool/pp.html
# Name: Privacy Policy, Length: 29999, dtype: object

# %%
df['Scraped Time']
# Out:
# 0        2021-06-15 20:19:35
# 1        2021-06-15 20:19:35
# 2        2021-06-15 20:19:35
# 3        2021-06-15 20:19:35
# 4        2021-06-15 20:19:35
#                 ...
# 29995    2021-06-15 20:49:15
# 29996    2021-06-15 20:49:15
# 29997    2021-06-15 20:49:15
# 29998    2021-06-15 20:49:15
# 29999    2021-06-15 20:49:15
# Name: Scraped Time, Length: 29999, dtype: object

# %%
df['Free']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 29995    True
# 29996    True
# 29997    True
# 29998    True
# 29999    True
# Name: Free, Length: 29999, dtype: bool

# %% [markdown]
# Creataing the column type for free and paid Apps by using the Free column, it's helpfull while dealing with the paid and Free Apps

# %%
df['Type'] = np.where(df['Free'] == True,'Free','Paid')
df.drop(['Free'],axis=1, inplace= True )

# %% [markdown]
# let's clean the Content Rating column

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           26193
# Teen                2602
# Mature 17+           761
# Everyone 10+         438
# Unrated                3
# Adults only 18+        2
# Name: Content Rating, dtype: int64

# %% [markdown]
# ## Observation :
# 1. we have varies Categories in the content Rating column :
#    * Everyone
#    * Teen
#    * Mature 17+
#    * Everyone 10+
#    * Unrated
#    * Adults only 18+
#
# Now, we makes this Categories to a simple 3 Categories for better understanding :
#    Everyone, Teen, Adults
#
#    * Mature 17+   ----> to Adults
#    * Everyone 10+ ----> to Teen
#    * Unrated      ----> to Everyone
#    * Adults only 18+ -> to Adults

# %%
df["Content Rating"]=df["Content Rating"].replace("Unrated","Everyone")
df["Content Rating"]=df["Content Rating"].replace("Everyone 10+","Teen")
df["Content Rating"]=df["Content Rating"].replace("Mature 17+","Adults")
df["Content Rating"]=df["Content Rating"].replace("Adults only 18+","Adults")

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29999 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           29999 non-null  object
#  1   App Id             29999 non-null  object
#  2   Category           29999 non-null  object
#  3   Rating             29729 non-null  float64
#  4   Rating Count       29729 non-null  float64
#  5   Installs           29999 non-null  int64
#  6   Minimum Installs   29999 non-null  float64
#  7   Maximum Installs   29999 non-null  int64
#  8   Price              29999 non-null  float64
#  9   Currency           29999 non-null  object
#  10  Size               29999 non-null  float64
#  11  Minimum Android    29912 non-null  object
#  12  Developer Id       29999 non-null  object
#  13  Developer Website  20140 non-null  object
#  14  Developer Email    29999 non-null  object
#  15  Released           29148 non-null  object
#  16  Last Updated       29999 non-null  object
#  17  Content Rating     29999 non-null  object
#  18  Privacy Policy     24587 non-null  object
#  19  Ad Supported       29999 non-null  bool
#  20  In App Purchases   29999 non-null  bool
#  21  Editors Choice     29999 non-null  bool
#  22  Scraped Time       29999 non-null  object
#  23  Type               29999 non-null  object
# dtypes: bool(3), float64(5), int64(2), object(14)
# memory usage: 5.1+ MB

# %%
df['Rating'].unique()
# Out:
# array([0. , 4.4, 5. , 4.5, 2. , 4.7, 4.9, 3.9, 3.7, 4.2, 3.4, 3.8, 4.6,
#        4.1, 2.5, 2.3, 2.1, 2.7, 4.3, 3.1, 4.8, 3.3, 4. , 2.4, 3.2, 3.6,
#        2.6, nan, 1.5, 3.5, 2.9, 1.3, 2.8, 3. , 2.2, 1.8, 1.4, 1.2, 1.9,
#        1.7, 1.6, 1. , 1.1])

# %%
df['Rating Count'].unique()
# Out:
# array([0.0000e+00, 6.4000e+01, 5.0000e+00, ..., 7.5400e+02, 8.6700e+02,
#        1.3778e+04])

# %% [markdown]
# let's change the Rating Count to certain ranges for the better understanding the data

# %%
df['Rating Count'].max()
# Out:
# 4275556.0

# %%
df['Rating Type'] = 'NoRatingProvided'
df.loc[(df['Rating Count'] > 0) & (df['Rating Count'] <= 10000.0),'Rating Type'] = 'Less than 10K'
df.loc[(df['Rating Count'] > 10000) & (df['Rating Count'] <= 500000.0),'Rating Type'] = 'Between 10K and 500K'
df.loc[(df['Rating Count'] > 500000) & (df['Rating Count'] <= 138557570.0),'Rating Type'] = 'More than 500K'
df['Rating Type'].value_counts()
# Out:
# Less than 10K           15569
# NoRatingProvided        13969
# Between 10K and 500K      441
# More than 500K             20
# Name: Rating Type, dtype: int64

# %%
df['Rating Type']
# Out:
# 0        NoRatingProvided
# 1           Less than 10K
# 2        NoRatingProvided
# 3           Less than 10K
# 4        NoRatingProvided
#                ...
# 29995    NoRatingProvided
# 29996       Less than 10K
# 29997    NoRatingProvided
# 29998       Less than 10K
# 29999       Less than 10K
# Name: Rating Type, Length: 29999, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29999 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App Name           29999 non-null  object
#  1   App Id             29999 non-null  object
#  2   Category           29999 non-null  object
#  3   Rating             29729 non-null  float64
#  4   Rating Count       29729 non-null  float64
#  5   Installs           29999 non-null  int64
#  6   Minimum Installs   29999 non-null  float64
#  7   Maximum Installs   29999 non-null  int64
#  8   Price              29999 non-null  float64
#  9   Currency           29999 non-null  object
#  10  Size               29999 non-null  float64
#  11  Minimum Android    29912 non-null  object
#  12  Developer Id       29999 non-null  object
#  13  Developer Website  20140 non-null  object
#  14  Developer Email    29999 non-null  object
#  15  Released           29148 non-null  object
#  16  Last Updated       29999 non-null  object
#  17  Content Rating     29999 non-null  object
#  18  Privacy Policy     24587 non-null  object
#  19  Ad Supported       29999 non-null  bool
#  20  In App Purchases   29999 non-null  bool
#  21  Editors Choice     29999 non-null  bool
#  22  Scraped Time       29999 non-null  object
#  23  Type               29999 non-null  object
#  24  Rating Type        29999 non-null  object
# dtypes: bool(3), float64(5), int64(2), object(15)
# memory usage: 5.3+ MB

# %% [markdown]
# # Question and Aswers :
#
#
# *  What are the top 10 Categories that are installed from the Google Play Store ?
# *  Which are the Categories that are getting installed the most in top 10 Categories?
# *  What is the higest rated Category ?
#
# *  Which Category has the highest Paid and Free apps ?
# *  How does the size of the Application impacts the Installation ?
#
# *  What are the Top 5 Paid Apps based With highest ratings and installs ?
# *  What are the Top 5 Free Apps based With highest      ratings and installs ?

# %% [markdown]
# ## Q - What are the top 10 Categories that are installed from the Google Play Store ?

# %%
df['Category'].unique()
# Out:
# array(['Adventure', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization', 'Racing',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Puzzle', 'Entertainment',
#        'Arcade', 'Auto & Vehicles', 'Photography', 'Health & Fitness',
#        'Education', 'Shopping', 'Board', 'Music & Audio', 'Sports',
#        'Beauty', 'Business', 'Educational', 'Finance', 'News & Magazines',
#        'Casual', 'Art & Design', 'House & Home', 'Card', 'Events',
#        'Trivia', 'Weather', 'Strategy', 'Word', 'Video Players & Editors',
#        'Action', 'Simulation', 'Music', 'Dating', 'Role Playing',
#        'Casino', 'Comics', 'Parenting'], dtype=object)

# %%
top_Category = df.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})

# %%
top_Category
# Out:
#                    Category  Count
# 0                 Education   3096
# 1             Music & Audio   2066
# 2                  Business   1853
# 3                     Tools   1842
# 4             Entertainment   1747
# 5         Books & Reference   1509
# 6                 Lifestyle   1496
# 7           Personalization   1165
# 8              Productivity   1100
# 9          Health & Fitness   1080
# 10                 Shopping   1023
# 11             Food & Drink    963
# 12           Travel & Local    915
# 13                  Finance    889
# 14                   Casual    689
# 15                   Arcade    652
# 16                   Puzzle    648
# 17                   Social    609
# 18            Communication    599
# 19                   Sports    568
# 20         News & Magazines    535
# 21              Photography    449
# 22                  Medical    418
# 23        Maps & Navigation    381
# 24                   Action    361
# 25               Simulation    308
# 26                Adventure    306
# 27              Educational    266
# 28          Auto & Vehicles    249
# 29             Art & Design    229
# 30             House & Home    191
# 31  Video Players & Editors    185
# 32                   Events    158
# 33                    Board    145
# 34                   Beauty    143
# 35             Role Playing    139
# 36                   Racing    137
# 37                   Trivia    122
# 38                 Strategy    119
# 39                     Word    107
# 40                     Card     97
# 41                  Weather     85
# 42                   Dating     80
# 43                    Music     71
# 44         Libraries & Demo     70
# 45                   Casino     62
# 46                Parenting     44
# 47                   Comics     33

# %%
Category_installs = df.groupby(['Category'])[['Installs']].sum()

# %%
Category_installs
# Out:
#                            Installs
# Category
# Action                    202765002
# Adventure                 153120873
# Arcade                    106950396
# Art & Design               17195598
# Auto & Vehicles             7261579
# Beauty                      4151066
# Board                      28930683
# Books & Reference          47087546
# Business                   14056233
# Card                       14686180
# Casino                      8646665
# Casual                    137623698
# Comics                       442851
# Communication              31450928
# Dating                      4217006
# Education                 108353349
# Educational                37498517
# Entertainment              97201403
# Events                       318876
# Finance                    58531571
# Food & Drink                8090966
# Health & Fitness           40962512
# House & Home                7454882
# Libraries & Demo           10894542
# Lifestyle                  55525340
# Maps & Navigation          26388297
# Medical                    12690399
# Music                       6010392
# Music & Audio              76570404
# News & Magazines          118393139
# Parenting                    637961
# Personalization           176715063
# Photography                85375073
# Productivity             1583308192
# Puzzle                    195626211
# Racing                    186915526
# Role Playing               42358801
# Shopping                   16317799
# Simulation                121261086
# Social                     27934743
# Sports                    144736700
# Strategy                   13216678
# Tools                     247418444
# Travel & Local            122756505
# Trivia                      3180548
# Video Players & Editors   131506736
# Weather                    23343878
# Word                       35789912

# %%
top_Category_installs = pd.merge(top_Category, Category_installs, on='Category')
top_Category_installs.head(5)
# Out:
#         Category  Count   Installs
# 0      Education   3096  108353349
# 1  Music & Audio   2066   76570404
# 2       Business   1853   14056233
# 3          Tools   1842  247418444
# 4  Entertainment   1747   97201403

# %%
top_10_Categories_installs = top_Category_installs.head(10).sort_values(by = ['Installs'],ascending = False)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Top 10 Installed Categories")
sns.barplot(x = top_10_Categories_installs.Category,y= top_10_Categories_installs.Installs)
# Out:
# <Axes: title={'center': 'Top 10 Installed Categories'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# ## Ans - Productivity,Tools,Personalization,Education, Entertainment ,Music & Audio,  Lifestyle,Books & Reference, Health & Fitness, Business

# %% [markdown]
# ## Q -  What are the 10 Categories in playstore as per the count?

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Top 10 Categories")
sns.barplot(x = top_10_Categories_installs.Category, y = top_10_Categories_installs.Count)
# Out:
# <Axes: title={'center': 'Top 10 Categories'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# ##Ans - Education, Music & Audio, Tools, Business, Entertainment, Books & Reference, Lifestyle, Personalization, Health & Fitness, Productivity.

# %% [markdown]
# ## Observation :
# As we can see from the above two plots: Maxinum number of apps present in google play store comes under Education Tools, Business and Entertainment etc., Categories but as per the installation scenario it is different. Maximum installed apps comes under Tools, Productivity,Entertainment, Music & Audio etc.,

# %% [markdown]
# ## visualize Total Categories and the count of Apps in each category

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Total Categories and count of Applications in each category ")
sns.barplot(x = top_Category_installs.Category, y = top_Category_installs.Count)
# Out:
# <Axes: title={'center': 'Total Categories and count of Applications in each category '}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# ## Visualize Total Categories and installed Applications in each category

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Total Categories and Installation of Applications in each category ")
sns.barplot(x = top_Category_installs.Category,y = top_Category_installs.Installs)
# Out:
# <Axes: title={'center': 'Total Categories and Installation of Applications in each category '}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# Rating distribution

# %%
plt.figure(figsize=(14,7))
g = sns.kdeplot(df.Rating, color="Blue", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
# Out:
# <ipython-input-177-a21c6a2a3d2d>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   g = sns.kdeplot(df.Rating, color="Blue", shade = True)
# Text(0.5, 1.0, 'Distribution of Rating')

# %%
plt.title("Rating")
sns.histplot(df.Rating,kde=True,bins=5)
# Out:
# <Axes: title={'center': 'Rating'}, xlabel='Rating', ylabel='Count'>

# %% [markdown]
# ## Observation :
# From the above two plots we can see that most people does not give a rating,But one more thing that comes out from this graph as well is that people tend to give 4+ rating the most.

# %% [markdown]
# ##Q - What is the highest rated Category?

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Highest Rated Category")
plt.ylabel("Number of applications")
plt.title("All Categories Rating ")
sns.barplot(x = df.Category,y = df.Rating)
# Out:
# <Axes: title={'center': 'All Categories Rating '}, xlabel='Category', ylabel='Rating'>

# %% [markdown]
# ## Ans - From the above plot we can see that Simulation is the highest Rated category

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
plt.figure(figsize=(8,8))
plt.title("Content Rating and Maximum installations ")
sns.scatterplot(x='Maximum Installs',y='Rating Count',data=df,hue='Content Rating')
# Out:
# <Axes: title={'center': 'Content Rating and Maximum installations '}, xlabel='Maximum Installs', ylabel='Rating Count'>

# %% [markdown]
# ## Observation :
# This scatterplot shows us that:
#  If we exclude everyone from the plot and when focus on Teen and Adults we can see that teens have much engagement in terms of download and rating count.

# %% [markdown]
# ##Q - Which Category has the highest Paid and Free apps ?

# %%
app_count = df.groupby(['Category','Type'])[['App Name']].count().reset_index().rename(columns={'App Name':'Count','index':'App Name'})
df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()
# Out:
# <ipython-input-185-c3390bac1d36>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()

# %%
df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9)) # try df_app_count.plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Free and Paid Apps in Category")
# Out:
# Text(0.5, 1.0, 'Free and Paid Apps in Category')

# %% [markdown]
# ## Ans - Education Category is the highest in paid apps list

# %% [markdown]
# ## Observation :
# It looks like certain app categories have more free apps available for download than others. In our dataset, the majority of apps in Business,Education, Music & Audio, Tools as well as Social categories were free to install. At the same time Books & References, Education, Tools and Personalization categories had the biggest number of paid apps available for Installation.

# %% [markdown]
# ##visualize the Installation Types in each category

# %%
df['Installs'].min(),df['Installs'].max()
# Out:
# (0, 1000000000)

# %% [markdown]
# There is a high variance in the number of installs, we need to reduce it so we can use a log value for this column, otherwise it would be unable to see the data when we visualize

# %%
categoty_type_installs = df.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type_installs['log_Installs'] = np.log10(categoty_type_installs['Installs'])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed Apps type wise according to Category")
sns.barplot(x = 'Category', y = 'log_Installs', hue='Type', data=categoty_type_installs)
# Out:
# <Axes: title={'center': 'Number of installed Apps type wise according to Category'}, xlabel='Category', ylabel='log_Installs'>

# %% [markdown]
# ##Q - How does the size of the Application impacts the Installation ?

# %%
df['log_Installs'] = np.log10(categoty_type_installs['Installs'])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Size")
plt.ylabel("Installs")
plt.title("Impact of Application Size in Installation")
sns.scatterplot(x = 'Size',y = 'Installs', hue='Type', data=df)
# Out:
# <Axes: title={'center': 'Impact of Application Size in Installation'}, xlabel='Size', ylabel='Installs'>

# %% [markdown]
# ##Ans - from the above plot we can see that size impacts the number of installations. Applications with large size are less installed by the user.

# %% [markdown]
# ## Let's see some correlations

# %%
df.corr()
# Out:
# <ipython-input-192-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Rating  Rating Count  Installs  Minimum Installs  \
# Rating            1.000000      0.045331  0.021443          0.021443
# Rating Count      0.045331      1.000000  0.443217          0.443217
# Installs          0.021443      0.443217  1.000000          1.000000
# Minimum Installs  0.021443      0.443217  1.000000          1.000000
# Maximum Installs  0.022611      0.450720  0.987777          0.987777
# Price            -0.005167     -0.001202 -0.000856         -0.000856
# Size              0.038483      0.027750  0.009276          0.009276
# Ad Supported      0.162423      0.023640  0.002997          0.002997
# In App Purchases  0.150391      0.088093  0.024538          0.024538
# Editors Choice    0.013703      0.114944  0.014104          0.014104
# log_Installs     -0.078385     -0.108373 -0.020579         -0.020579
#
#                   Maximum Installs     Price      Size  Ad Supported  \
# Rating                    0.022611 -0.005167  0.038483      0.162423
# Rating Count              0.450720 -0.001202  0.027750      0.023640
# Installs                  0.987777 -0.000856  0.009276      0.002997
# Minimum Installs          0.987777 -0.000856  0.009276      0.002997
# Maximum Installs          1.000000 -0.000907  0.010174      0.004418
# Price                    -0.000907  1.000000  0.004909     -0.036793
# Size                      0.010174  0.004909  1.000000     -0.047474
# Ad Supported              0.004418 -0.036793 -0.047474      1.000000
# In App Purchases          0.025823 -0.002259  0.168239      0.124921
# Editors Choice            0.015906  0.003701  0.016075     -0.004614
# log_Installs             -0.062481       NaN  0.177106      0.134490
#
#                   In App Purchases  Editors Choice  log_Installs
# Rating                    0.150391        0.013703     -0.078385
# Rating Count              0.088093        0.114944     -0.108373
# Installs                  0.024538        0.014104     -0.020579
# Minimum Installs          0.024538        0.014104     -0.020579
# Maximum Installs          0.025823        0.015906     -0.062481
# Price                    -0.002259        0.003701           NaN
# Size                      0.168239        0.016075      0.177106
# Ad Supported              0.124921       -0.004614      0.134490
# In App Purchases          1.000000        0.039009     -0.071445
# Editors Choice            0.039009        1.000000           NaN
# log_Installs             -0.071445             NaN      1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# Out:
# <ipython-input-193-20339db5f703>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# <Axes: >

# %% [markdown]
# ##Observation :
#  Factors like AdSupport and InappPurchases are correlated to app rating. So we can say that if the app provides customer support and have subscription plans we can engage more customers. We can also see from the same graph that the editor's choice plays a important role as well. With high editor choice we can see high ratings count and high installs.

# %% [markdown]
# ##Q - What are the Top 5 Paid Apps based With highest ratings and installs ?

# %%
df['Installs'].mean()
# Out:
# 153400.80499349977

# %%
paid_apps = df[(df.Type=='Paid') & (df.Installs >= df["Installs"].mean())]
paid_apps = paid_apps.groupby('App Name')['Rating'].max().sort_values(ascending = False)

# %%
plt.figure(figsize=(8,4))
plt.xlabel("Rating")
sns.set_theme(style="whitegrid")
plt.title("Top 5 Paid Rated Apps")
sns.lineplot(x=paid_apps.values,y=paid_apps.index,color='Blue')
# Out:
# <Axes: title={'center': 'Top 5 Paid Rated Apps'}, xlabel='Rating', ylabel='App Name'>

# %% [markdown]
# ## Ans - The Hunt for the lost treasure True Skate, Survival craft, Draw something,ezPDF Reader PDF Annotate Form

# %% [markdown]
# ##Q - What are the Top 5 Free Apps based With highest ratings and installs ?

# %%
free_apps = df[(df.Type=='Free') & (df.Installs >= df["Installs"].mean())]
free_apps = free_apps.groupby('App Name')['Rating'].max().sort_values(ascending = False)
free_apps = free_apps.head(5)

# %%
plt.figure(figsize=(8,4))
plt.xlabel("Rating")
sns.set_theme(style="whitegrid")
plt.title("Top 5 Free Rated Apps")
sns.lineplot(x = free_apps.values, y = free_apps.index,color = 'Blue')
# Out:
# <Axes: title={'center': 'Top 5 Free Rated Apps'}, xlabel='Rating', ylabel='App Name'>

# %% [markdown]
# ## Ans - ..., ..., Urdu Poetry, Police Elephant Robot Game: Police Transport Games, BKM Express.

# %% [markdown]
# ## Visualize the categories that have the Top 10  Max Installations

# %%
plt.figure(figsize=(8,6))
data = df.groupby('Category')['Maximum Installs'].max().sort_values(ascending = True)
data = data.head(10)
labels = data.keys()
plt.pie(data, labels= labels,autopct='%.0f%%')
plt.title("Top 10 Max installations Category wise", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Top 10 Max installations Category wise')

# %% [markdown]
# ## Visualize the Top 10 installation Categories that Adults have installed the most

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
plt.figure(figsize=(8,6))
Adult = df[(df['Content Rating']=='Adults')]
Adult = Adult.groupby(['Category'])['Maximum Installs'].max().sort_values(ascending=False)
Adult = Adult.head(10)
labels = Adult.keys()
plt.pie(x = Adult, autopct="%.1f%%", labels=labels)
plt.title("Adults Installing apps in terms of category", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Adults Installing apps in terms of category')

# %% [markdown]
# ## Observation :
# Most of the Adults showing intrest in downloading the Tools, Action and Books and Reference

# %% [markdown]
# ## visualize Teens Installing the apps in terms of Category

# %%
plt.figure(figsize=(8,6))
Teen = df[(df['Content Rating']=='Teen')]
Teen = Teen.groupby(['Category'])['Maximum Installs'].max().sort_values(ascending=False)
Teen = Teen.head(10)
labels = Teen.keys()
plt.pie(x = Teen, autopct="%.1f%%", labels=labels)
plt.title("Teen Installing apps in terms of category", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Teen Installing apps in terms of category')

# %% [markdown]
# # **Summary and Conclusion** :
# * People are more intrested to install the gaming Apps, the top Rating is given to the gaming apps.
# * InAppPurchases are correlated to App rating. So we can say that if the app provides customer support and have subscription plans it will helps to engage customers.
# * most people does not gave rating, But the people who are given rating are tend to give 4+ rating the most.
# * Most of the Audlts installed the Social and communication Apps.
# * Most of the installations are done by the teens and the most are Video Players and Editors. Video Players and Editors has more demand.
# * Size of the Application varies the installations.
# * People are mostly dwonladed the free apps the installation of the free apps is high and the availabilty of the free apps also is very high.

# %% [markdown]
# ## **FURTHER ANALYSIS**
# # **PREDICT GOOGLE PLAYSTORE RATINGS**
# We have successfully done exploratory data analysis on above data. Now Our objective is to develop a predictive model that can accurately predict app ratings based on various features and attributes present in the Google Playstore dataset. By training this model, we aim to provide app developers and stakeholders with a tool to estimate the potential ratings of their apps and make informed decisions to improve user satisfaction and app performance.
#
# Based on the heatmap results from above and the importance of category attribute for  the user; we decided to include all the  four attributes (`Rating Count`, `size`, `installs`,`Content rating`, and `category` ) in defining the app profile
# whereas `ratings` will be choosen as the label for our model
#
# We will be importing python library `sklearn` which provides simple and efficient tools for predictive data analysis

# %%
from sklearn import metrics
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# Following above data cleaning activities , our columns `size`,`installs` are now ready to be fed into the model but we still need to one-hot encode `category`and `Content rating`.

# %%
# Category features encoding
category_list = df['Category'].unique().tolist()
category_list = ['cat_' + word for word in category_list]
df = pd.concat([df, pd.get_dummies(df['Category'], prefix='cat')], axis=1)

# %%
# Encode Content Rating features
le = preprocessing.LabelEncoder()
df['Content Rating'] = le.fit_transform(df['Content Rating'])

# %%
# Split data into training and testing sets
features = ['Rating Count', 'Size', 'Installs', 'Content Rating',]
features.extend(category_list)
df.fillna({'Rating':df['Rating'].mean(),'Rating Count':df['Rating Count'].mean()},inplace=True) #Just for the model to work correctly otherwise ratings should be filled by other business techniques
X = df[features]
y = df['Rating']

# %%
# Split the dataset into 75% train data and 25% test data.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 10)

# %% [markdown]
# We can use KNN solve complicated problems. With the help of KNN we can do pattern recognition and data mining. KNN defines the similarity. From the given dataset KNN finds common groups between attributes

# %%
# Look at the 8 closest neighbors
model = KNeighborsRegressor(n_neighbors=8)
df.isnull().sum().sort_values(ascending = False)
# Out:
# log_Installs         29909
# Developer Website     9859
# Privacy Policy        5412
# Released               851
# Minimum Android         87
#                      ...
# cat_Business             0
# cat_Card                 0
# cat_Casino               0
# App Id                   0
# cat_Word                 0
# Length: 74, dtype: int64

# %%
# Find the mean accuracy of knn regression using X_test and y_test
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
# Calculate the mean accuracy of the KNN model
accuracy = model.score(X_test,y_test)
'Accuracy: ' + str(np.round(accuracy*100, 2)) + '%'
# Out:
# 'Accuracy: 93.43%'

# %% [markdown]
# Hence Now our model can predict ratings for unseen apps with 93% accuracy

# %%
# Try different numbers of n_estimators - this will take a minute or so
n_neighbors = np.arange(1, 20, 1)
scores = []
for n in n_neighbors:
    model.set_params(n_neighbors=n)
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))
plt.figure(figsize=(7, 5))
plt.title("Effect of Estimators")
plt.xlabel("Number of Neighbors K")
plt.ylabel("Score")
plt.plot(n_neighbors, scores)
